# %%
temp = "Python String"
print(temp)

# %%
help(str)

# %%
dir(str)

# %%
str_variable = "python is good Language"

# %%
str_variable.capitalize()
# 'Python is good language'

# %%
str_variable.lower()
# 'python is good language'

# %%
str_variable.upper()
# 'PYTHON IS GOOD LANGUAGE'

# %%
str_variable.title()
# 'Python Is Good Language'

# %%
str_variable.swapcase()
# 'PYTHON IS GOOD lANGUAGE'

# %%
str_variable.count("is")
# 1

# %%
str_variable.find("good")
# 10

# %%
str_variable.find("Python")

# %%
str_variable.index("good")
# 10

# %%
str_variable.index("Python")
# 10

# %%
str_variable.rfind("o")
# 12

# %%
str_variable.rindex("o")
# 12

# %%
str_variable.rindex("pp")

# %%
str_variable.isalnum()
# False

# %%
str_variable1 = "Python123"
str_variable1.isalnum()

# %%
print(str_variable)
str_variable2 = "Python"
str_variable2.isalpha()
# False

# %%
str_variable.isdecimal()
# False

# %%
str_variable.isalnum()
# False

str_variable.isalpha()
# False

str_variable.isascii()
# True

str_variable.isdecimal()
# False

str_variable.isdigit()
# False

str_variable.isidentifier()
# False

str_variable.islower()
# False

str_variable.isnumeric()
# False

str_variable.isprintable()
# True

str_variable.isspace()
# False

str_variable.istitle()
# False

str_variable.isupper()
# False

# %%
str_variable.replace("good", "great")
# 'python is great Language'

str_variable.strip()
# From " python is good Language  "
# 'python is good Language'

str_variable.lstrip()
# 'python is good Language'

str_variable.rstrip()
# 'python is good Language'

# %%
str_variable.split()
# ['python', 'is', 'good', 'Language']

# %%
str_variable4 = "1,Python,Language,3.12,Windows"
str_variable4.split(",")

# %%
str_variable4 = "1||Python||Language||3.12||Windows"
list_str4 = str_variable4.split("||")
list_str4

# %%
"#".join(list_str4)

# %%
str_variable.startswith("python")
# True

str_variable.endswith("Language")
# True

# %%
str_variable.partition("is")
# ('python ', 'is', ' good Language')

# %%
str_variable6 = "Python is great language and it is easy to learn."
str_variable6.partition("is")
# ('python ', 'is', ' good Language')

# %%
str_variable6 = "Python is great language and it is easy to learn."
str_variable6.partition("not")
